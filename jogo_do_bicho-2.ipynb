# %% [markdown]
# # Relações do jogo do bicho
#
# ![](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.gANbKRY9lylp2z_pQtueowHaF7%26pid%3DApi&f=1&ipt=9ebc360ae28ff64be7557725a38d90cca82ea51748cc076b536e7f6eef9ba78a&ipo=images)

# %%
relacao_g = {
    'Avestruz': 1,
    'Águia': 2,
    'Burro': 3,
    'Borboleta': 4,
    'Cachorro': 5,
    'Cabra': 6,
    'Carneiro': 7,
    'Camelo': 8,
    'Cobra': 9,
    'Coelho': 10,
    'Cavalo': 11,
    'Elefante': 12,
    'Galo': 13,
    'Gato': 14,
    'Jacaré': 15,
    'Leão': 16,
    'Macaco': 17,
    'Porco': 18,
    'Pavão': 19,
    'Peru': 20,
    'Touro': 21,
    'Tigre': 22,
    'Urso': 23,
    'Veado': 24,
    'Vaca': 25
}


relacao_n = {
    1: 'Avestruz',
    2: 'Avestruz',
    3: 'Avestruz',
    4: 'Avestruz',
    5: 'Águia',
    6: 'Águia',
    7: 'Águia',
    8: 'Águia',
    9: 'Burro',
    10: 'Burro',
    11: 'Burro',
    12: 'Burro',
    13: 'Borboleta',
    14: 'Borboleta',
    15: 'Borboleta',
    16: 'Borboleta',
    17: 'Cachorro',
    18: 'Cachorro',
    19: 'Cachorro',
    20: 'Cachorro',
    21: 'Cabra',
    22: 'Cabra',
    23: 'Cabra',
    24: 'Cabra',
    25: 'Carneiro',
    26: 'Carneiro',
    27: 'Carneiro',
    28: 'Carneiro',
    29: 'Camelo',
    30: 'Camelo',
    31: 'Camelo',
    32: 'Camelo',
    33: 'Cobra',
    34: 'Cobra',
    35: 'Cobra',
    36: 'Cobra',
    37: 'Coelho',
    38: 'Coelho',
    39: 'Coelho',
    40: 'Coelho',
    41: 'Cavalo',
    42: 'Cavalo',
    43: 'Cavalo',
    44: 'Cavalo',
    44: 'Cavalo',
    45: 'Elefante',
    46: 'Elefante',
    47: 'Elefante',
    48: 'Elefante',
    49: 'Galo',
    50: 'Galo',
    51: 'Galo',
    52: 'Galo',
    53: 'Gato',
    54: 'Gato',
    55: 'Gato',
    56: 'Gato',
    57: 'Jacaré',
    58: 'Jacaré',
    59: 'Jacaré',
    60: 'Jacaré',
    61: 'Leão',
    62: 'Leão',
    63: 'Leão',
    64: 'Leão',
    65: 'Macaco',
    66: 'Macaco',
    67: 'Macaco',
    68: 'Macaco',
    69: 'Porco',
    70: 'Porco',
    71: 'Porco',
    72: 'Porco',
    73: 'Pavão',
    74: 'Pavão',
    75: 'Pavão',
    76: 'Pavão',
    77: 'Peru',
    78: 'Peru',
    79: 'Peru',
    80: 'Peru',
    81: 'Touro',
    82: 'Touro',
    83: 'Touro',
    84: 'Touro',
    85: 'Tigre',
    86: 'Tigre',
    87: 'Tigre',
    88: 'Tigre',
    89: 'Urso',
    90: 'Urso',
    91: 'Urso',
    92: 'Urso',
    93: 'Veado',
    94: 'Veado',
    95: 'Veado',
    96: 'Veado',
    97: 'Vaca',
    98: 'Vaca',
    99: 'Vaca',
    0: 'Vaca',
}

# %%
from pandas import read_csv

df = read_csv('/content/resultados_numeros_data.csv')

# %%
from pandas import Series

grupos = Series(relacao_g)

numeros = Series(relacao_n)

# %%
df
# Out:
#            data  milhar
# 0    2022-09-24    8982
# 1    2022-09-23    6690
# 2    2022-09-22    8679
# 3    2022-09-21    5613
# 4    2022-09-20    6680
# ..          ...     ...
# 242  2021-08-12    5452
# 243  2021-07-12     290
# 244  2021-06-12    1121
# 245  2021-04-12    1929
# 246  2021-03-12    3945
#
# [247 rows x 2 columns]

# %%
numeros
# Out:
# 1     Avestruz
# 2     Avestruz
# 3     Avestruz
# 4     Avestruz
# 5        Águia
#         ...
# 96       Veado
# 97        Vaca
# 98        Vaca
# 99        Vaca
# 0         Vaca
# Length: 100, dtype: object

# %%
grupos
# Out:
# Avestruz      1
# Águia         2
# Burro         3
# Borboleta     4
# Cachorro      5
# Cabra         6
# Carneiro      7
# Camelo        8
# Cobra         9
# Coelho       10
# Cavalo       11
# Elefante     12
# Galo         13
# Gato         14
# Jacaré       15
# Leão         16
# Macaco       17
# Porco        18
# Pavão        19
# Peru         20
# Touro        21
# Tigre        22
# Urso         23
# Veado        24
# Vaca         25
# dtype: int64

# %%
def numero_animal(n, numeros=numeros):
    return numeros.loc[n]
print(numero_animal(74))
# Out:
# Pavão

# %%
def grupo_animal(animal, grupos=grupos):
  return grupos.loc[animal]
grupo_animal(numero_animal(4))
# Out:
# np.int64(1)

# %%
df
# Out:
#            data  milhar
# 0    2022-09-24    8982
# 1    2022-09-23    6690
# 2    2022-09-22    8679
# 3    2022-09-21    5613
# 4    2022-09-20    6680
# ..          ...     ...
# 242  2021-08-12    5452
# 243  2021-07-12     290
# 244  2021-06-12    1121
# 245  2021-04-12    1929
# 246  2021-03-12    3945
#
# [247 rows x 2 columns]

# %%
df.index = df.data # transformando a data em index
del df['data'] #deletando a tabela repetida

# %%
df
# Out:
#             milhar
# data
# 2022-09-24    8982
# 2022-09-23    6690
# 2022-09-22    8679
# 2022-09-21    5613
# 2022-09-20    6680
# ...            ...
# 2021-08-12    5452
# 2021-07-12     290
# 2021-06-12    1121
# 2021-04-12    1929
# 2021-03-12    3945
#
# [247 rows x 1 columns]

# %%
df['resultado_01'] = df.milhar.apply(
    lambda x: int(str(x).zfill(4)[2:]) #transformando em string para poder dar um fill
                                      #transformar 290 -> 0290 e depois pegando os 2 primeiros digitos
)

df['resultado_02'] = df.milhar.apply(
    lambda x: int(str(x).zfill(4)[:2])
)

# %%
df
# Out:
#             milhar  resultado_01  resultado_02
# data
# 2022-09-24    8982            82            89
# 2022-09-23    6690            90            66
# 2022-09-22    8679            79            86
# 2022-09-21    5613            13            56
# 2022-09-20    6680            80            66
# ...            ...           ...           ...
# 2021-08-12    5452            52            54
# 2021-07-12     290            90             2
# 2021-06-12    1121            21            11
# 2021-04-12    1929            29            19
# 2021-03-12    3945            45            39
#
# [247 rows x 3 columns]

# %%
df['bicho_01'] = df.resultado_01.apply(numero_animal)
df['bicho_02'] = df.resultado_02.apply(numero_animal)

# %%
df
# Out:
#             milhar  resultado_01  resultado_02   bicho_01  bicho_02
# data
# 2022-09-24    8982            82            89      Touro      Urso
# 2022-09-23    6690            90            66       Urso    Macaco
# 2022-09-22    8679            79            86       Peru     Tigre
# 2022-09-21    5613            13            56  Borboleta      Gato
# 2022-09-20    6680            80            66       Peru    Macaco
# ...            ...           ...           ...        ...       ...
# 2021-08-12    5452            52            54       Galo      Gato
# 2021-07-12     290            90             2       Urso  Avestruz
# 2021-06-12    1121            21            11      Cabra     Burro
# 2021-04-12    1929            29            19     Camelo  Cachorro
# 2021-03-12    3945            45            39   Elefante    Coelho
#
# [247 rows x 5 columns]

# %%
df['grupo_01'] = df.bicho_01.apply(grupo_animal)
df['grupo_02'] = df.bicho_02.apply(grupo_animal)

# %%
df
# Out:
#             milhar  resultado_01  resultado_02   bicho_01  bicho_02  grupo_01  \
# data
# 2022-09-24    8982            82            89      Touro      Urso        21
# 2022-09-23    6690            90            66       Urso    Macaco        23
# 2022-09-22    8679            79            86       Peru     Tigre        20
# 2022-09-21    5613            13            56  Borboleta      Gato         4
# 2022-09-20    6680            80            66       Peru    Macaco        20
# ...            ...           ...           ...        ...       ...       ...
# 2021-08-12    5452            52            54       Galo      Gato        13
# 2021-07-12     290            90             2       Urso  Avestruz        23
# 2021-06-12    1121            21            11      Cabra     Burro         6
# 2021-04-12    1929            29            19     Camelo  Cachorro         8
# 2021-03-12    3945            45            39   Elefante    Coelho        12
#
#             grupo_02
# ...

# %%
from seaborn import set

set()

(df
 .query('bicho_02 == "Galo"')
 .bicho_01
 .groupby(df.bicho_01).count().plot(kind='bar'))
# Out:
# <Axes: xlabel='bicho_01'>

# %%
df.query('bicho_02 == "Touro"')
# Out:
#             milhar  resultado_01  resultado_02 bicho_01 bicho_02  grupo_01  \
# data
# 2022-10-09    8178            78            81     Peru    Touro        20
# 2022-08-27    8192            92            81     Urso    Touro        23
# 2022-08-26    8240            40            82   Coelho    Touro        10
# 2022-06-25    8263            63            82     Leão    Touro        16
# 2022-02-06    8364            64            83     Leão    Touro        16
# 2022-05-27    8310            10            83    Burro    Touro         3
# 2022-04-27    8381            81            83    Touro    Touro        21
# 2022-08-04    8155            55            81     Gato    Touro        14
# 2022-04-04    8137            37            81   Coelho    Touro        10
# 2022-03-28    8433            33            84    Cobra    Touro         9
# 2022-05-03    8466            66            84   Macaco    Touro        17
# ...

# %%
df.query('bicho_02 == "Touro"').bicho_01.groupby(df.bicho_01).count()
# Out:
# bicho_01
# Burro     1
# Camelo    1
# Cobra     1
# Coelho    3
# Gato      1
# Leão      2
# Macaco    1
# Peru      1
# Touro     1
# Urso      1
# Name: bicho_01, dtype: int64
